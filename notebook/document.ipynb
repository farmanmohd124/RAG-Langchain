# %% [markdown]
# ### Data ingestion

# %%
### Document structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Mohd Farman",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Mohd Farman', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)


print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader
from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n    \n    \n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 0}, page_content='C++\t\r \xa0Foundation\t\r \xa0with\t\r \xa0Data\t\r \xa0Structures\t\r \xa0\nLecture\t\r \xa05\t\r \xa0\t\r \xa0:\t\r \xa0Functions,\t\r \xa0Variables\t\r \xa0and\t\r \xa0Scope\t\r \xa0\ns'),
#  Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 1}, page_content='Functions\t\r \xa0\n\t\r \xa0\n\t\r \xa0A\t\r \xa0Function\t\r \xa0is\t\r \xa0a\t\r \xa0collection\t\r \xa0of\t\r \xa0statements\t\r \xa0designed\t\r \xa0to\t\r \xa0perform\t\r \xa0a\t\r \xa0specific\t\r \xa0task.\t\r \xa0\nFunction\t\r \xa0is\t\r \xa0like\t\r \xa0a\t\r \xa0black\t\r \xa0box\t\r \xa0that\t\r \xa0can\t\r \xa0take\t\r \xa0certain\t\r \xa0input(s)\t\r \xa0as\t\r \xa0its\t\r \xa0parameters\t\r \xa0and\t\r \xa0\ncan\t\r \xa0output\t\r \xa0a\t\r \xa0value\t\r \xa0which\t\r \xa0is\t\r \xa0the\t\r \xa0return\t\r \xa0value.\t\r \xa0\t\r \xa0A\t\r \xa0function\t\r \xa0is\t\r \xa0created\t\r \xa0so\t\r \xa0that\t\r \xa0one\t\r \xa0\ncan\t\r \xa0use\t\r \xa0it\t\r \xa0as\t\r \xa0many\t\r \xa0time\t\r \xa0as\t\r \xa0needed\t\r \xa0just\t\r \xa0by\t\r \xa0using\t\r \xa0the\t\r \xa0name\t\r \xa0of\t\r \xa0the\t\r \xa0function,\t\r \xa0you\t\r \xa0\ndo\t\r \xa0not\t\r \xa0need\t\r \xa0to\t\r \xa0type\t\r \xa0the\t\r \xa0statements\t\r \xa0in\t\r \xa0the\t\r \xa0function\t\r \xa0every\t\r \xa0time\t\r \xa0required.\t\r \xa0\nDefining\t\r \xa0Function\t\r \xa0\nreturn_type\t\r \xa0\t\r \xa0function_name(parameter\t\r \xa01,\t\r \xa0parameter\t\r \xa02,\t\r \xa0………)\t\r \xa0{\t\r \xa0\nstatements;\t\r \xa0\n}\t\r \xa0\n\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\n\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\n• \xa0 return\t\r \xa0type:\t\r \xa0A\t\r \xa0function\t\r \xa0may\t\r \xa0return\t\r \xa0a\t\r \xa0value.\t\r \xa0The\t\r \xa0return\t\r \xa0type\t\r \xa0of\t\r \xa0the\t\r \xa0\nfunction\t\r \xa0is\t\r \xa0the\t\r \xa0data\t\r \xa0type\t\r \xa0of\t\r \xa0the\t\r \xa0value\t\r \xa0that\t\r \xa0function\t\r \xa0returns.\t\r \xa0Sometimes\t\r \xa0\nfunction\t\r \xa0is\t\r \xa0not\t\r \xa0required\t\r \xa0\t\r \xa0to\t\r \xa0return\t\r \xa0any\t\r \xa0value\t\r \xa0and\t\r \xa0still\t\r \xa0performs\t\r \xa0the\t\r \xa0\ndesired\t\r \xa0task.\t\r \xa0The\t\r \xa0return\t\r \xa0type\t\r \xa0of\t\r \xa0such\t\r \xa0functions\t\r \xa0is\t\r \xa0void.\t\r \xa0\n\t\r \xa0\nExample:\t\r \xa0\nFollowing\t\r \xa0is\t\r \xa0the\t\r \xa0example\t\r \xa0of\t\r \xa0a\t\r \xa0function\t\r \xa0that\t\r \xa0sum\t\r \xa0of\t\r \xa0two\t\r \xa0numbers.\t\r \xa0Here\t\r \xa0input\t\r \xa0to\t\r \xa0\nthe\t\r \xa0function\t\r \xa0are\t\r \xa0the\t\r \xa0numbers\t\r \xa0and\t\r \xa0output\t\r \xa0is\t\r \xa0their\t\r \xa0sum.\t\r \xa0\n\t\r \xa0\n1. \xa0 int\t\r \xa0findSum(\t\r \xa0int\t\r \xa0a,\t\r \xa0int\t\r \xa0b){\t\r \xa0\n2. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0sum\t\r \xa0=\t\r \xa0a\t\r \xa0+\t\r \xa0b;\t\r \xa0\n3. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0return\t\r \xa0\t\r \xa0sum;\t\r \xa0\n4. \xa0 }'),
#  Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 2}, page_content='Function\t\r \xa0Calling\t\r \xa0\nNow\t\r \xa0that\t\r \xa0we\t\r \xa0have\t\r \xa0read\t\r \xa0about\t\r \xa0how\t\r \xa0to\t\r \xa0create\t\r \xa0a\t\r \xa0function\t\r \xa0lets\t\r \xa0see\t\r \xa0how\t\r \xa0to\t\r \xa0call\t\r \xa0the\t\r \xa0\nfunction.\t\r \xa0To\t\r \xa0call\t\r \xa0the\t\r \xa0function\t\r \xa0you\t\r \xa0need\t\r \xa0to\t\r \xa0know\t\r \xa0the\t\r \xa0name\t\r \xa0of\t\r \xa0the\t\r \xa0function\t\r \xa0and\t\r \xa0\nnumber\t\r \xa0of\t\r \xa0parameters\t\r \xa0required\t\r \xa0and\t\r \xa0their\t\r \xa0data\t\r \xa0types\t\r \xa0and\t\r \xa0to\t\r \xa0collect\t\r \xa0the\t\r \xa0\nreturned\t\r \xa0value\t\r \xa0by\t\r \xa0the\t\r \xa0function\t\r \xa0you\t\r \xa0need\t\r \xa0to\t\r \xa0know\t\r \xa0the\t\r \xa0return\t\r \xa0type\t\r \xa0of\t\r \xa0the\t\r \xa0\nfunction.\t\r \xa0\t\r \xa0\nExample\t\r \xa0\n5. \xa0 #include<iostream>\t\r \xa0\n6. \xa0 using\t\r \xa0namespace\t\r \xa0std;\t\r \xa0\n7. \xa0 int\t\r \xa0findSum(\t\r \xa0int\t\r \xa0a,\t\r \xa0int\t\r \xa0b){\t\r \xa0\n8. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0sum\t\r \xa0=\t\r \xa0a\t\r \xa0+\t\r \xa0b;\t\r \xa0\n9. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0return\t\r \xa0\t\r \xa0sum;\t\r \xa0\n10. \xa0}\t\r \xa0\n11. \xa0int\t\r \xa0main\t\r \xa0()\t\r \xa0{\t\r \xa0\n12. \xa0\t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0a\t\r \xa0=\t\r \xa010,\t\r \xa0b\t\r \xa0=\t\r \xa020;\t\r \xa0\n13. \xa0\t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0c\t\r \xa0=\t\r \xa0findSum\t\r \xa0(a,\t\r \xa0b);\t\r \xa0//\t\r \xa0function\t\r \xa0findSum\t\r \xa0()\t\r \xa0is\t\r \xa0called\t\r \xa0using\t\r \xa0its\t\r \xa0name\t\r \xa0and\t\r \xa0\nby\t\r \xa0knowing\t\r \xa0\t\r \xa0\t\r \xa0\n14. \xa0\t\r \xa0\t\r \xa0\t\r \xa0cout<<\t\r \xa0c;\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0//\t\r \xa0the\t\r \xa0number\t\r \xa0of\t\r \xa0parameters\t\r \xa0and\t\r \xa0their\t\r \xa0data\t\r \xa0type.\t\r \xa0\n15. \xa0}\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0//\t\r \xa0integer\t\r \xa0c\t\r \xa0is\t\r \xa0used\t\r \xa0to\t\r \xa0collect\t\r \xa0the\t\r \xa0returned\t\r \xa0value\t\r \xa0by\t\r \xa0\nthe\t\r \xa0function\t\r \xa0\n\t\r \xa0\nOutput:\t\r \xa0\n30\t\r \xa0\n\t\r \xa0\nIMPORTANT\t\r \xa0POINTS:\t\r \xa0\n• \xa0 Number\t\r \xa0of\t\r \xa0parameter\t\r \xa0and\t\r \xa0their\t\r \xa0data\t\r \xa0type\t\r \xa0while\t\r \xa0calling\t\r \xa0must\t\r \xa0match\t\r \xa0with\t\r \xa0\nfunction\t\r \xa0signature.\t\r \xa0Consider\t\r \xa0the\t\r \xa0above\t\r \xa0example,\t\r \xa0while\t\r \xa0calling\t\r \xa0function\t\r \xa0\nfindSum\t\r \xa0()\t\r \xa0the\t\r \xa0number\t\r \xa0of\t\r \xa0parameters\t\r \xa0are\t\r \xa0two\t\r \xa0and\t\r \xa0both\t\r \xa0the\t\r \xa0parameter\t\r \xa0\nare\t\r \xa0of\t\r \xa0integer\t\r \xa0type.\t\r \xa0\n\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\n• \xa0 It\t\r \xa0is\t\r \xa0okay\t\r \xa0not\t\r \xa0to\t\r \xa0collect\t\r \xa0the\t\r \xa0return\t\r \xa0value\t\r \xa0of\t\r \xa0function.\t\r \xa0For\t\r \xa0example,\t\r \xa0in\t\r \xa0the\t\r \xa0\nabove\t\r \xa0c ...
#  Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 3}, page_content='• \xa0 void\t\r \xa0return\t\r \xa0type\t\r \xa0functions:\t\r \xa0These\t\r \xa0are\t\r \xa0the\t\r \xa0functions\t\r \xa0that\t\r \xa0do\t\r \xa0not\t\r \xa0return\t\r \xa0\nany\t\r \xa0value\t\r \xa0to\t\r \xa0calling\t\r \xa0function.\t\r \xa0These\t\r \xa0functions\t\r \xa0are\t\r \xa0created\t\r \xa0and\t\r \xa0used\t\r \xa0to\t\r \xa0\nperform\t\r \xa0specific\t\r \xa0task\t\r \xa0just\t\r \xa0like\t\r \xa0the\t\r \xa0normal\t\r \xa0function\t\r \xa0except\t\r \xa0they\t\r \xa0do\t\r \xa0not\t\r \xa0\nreturn\t\r \xa0a\t\r \xa0value\t\r \xa0after\t\r \xa0function\t\r \xa0executes.\t\r \xa0\n\t\r \xa0\nFollowing\t\r \xa0are\t\r \xa0some\t\r \xa0more\t\r \xa0examples\t\r \xa0of\t\r \xa0functions\t\r \xa0and\t\r \xa0their\t\r \xa0use\t\r \xa0to\t\r \xa0give\t\r \xa0you\t\r \xa0a\t\r \xa0\nbetter\t\r \xa0idea.\t\r \xa0\n\t\r \xa0\nFunction\t\r \xa0to\t\r \xa0find\t\r \xa0area\t\r \xa0of\t\r \xa0circle\t\r \xa0\n\t\r \xa0\n1. \xa0 #include<iostream>\t\r \xa0\n2. \xa0 using\t\r \xa0namespace\t\r \xa0std;\t\r \xa0\n3. \xa0 double\t\r \xa0findArea(\t\r \xa0double\t\r \xa0radius){\t\r \xa0\t\r \xa0\t\r \xa0//return\t\r \xa0type\t\r \xa0of\t\r \xa0the\t\r \xa0function\t\r \xa0is\t\r \xa0double.\t\r \xa0\n4. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0double\t\r \xa0area\t\r \xa0=\t\r \xa03.14\t\r \xa0*\t\r \xa0radius\t\r \xa0*\t\r \xa0radius;\t\r \xa0\n5. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0return\t\r \xa0\t\r \xa0area;\t\r \xa0\n6. \xa0 }\t\r \xa0\n7. \xa0 int\t\r \xa0main\t\r \xa0()\t\r \xa0{\t\r \xa0\n8. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0double\t\r \xa0radius\t\r \xa0=\t\r \xa05.8;\t\r \xa0\n9. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0double\t\r \xa0c\t\r \xa0=\t\r \xa0findArea\t\r \xa0(radius);\t\r \xa0\t\r \xa0\t\r \xa0\n10. \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0cout<<\t\r \xa0c;\t\r \xa0\n11. \xa0\t\r \xa0}\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\n\t\r \xa0\nFunction\t\r \xa0to\t\r \xa0print\t\r \xa0average\t\r \xa0\n\t\r \xa0\n1. \xa0 #include<iostream>\t\r \xa0\n2. \xa0 using\t\r \xa0namespace\t\r \xa0std;\t\r \xa0\n3. \xa0 \t\r \xa0\n4. \xa0 void\t\r \xa0printAverage(int\t\r \xa0a,\t\r \xa0int\t\r \xa0b\t\r \xa0){\t\r \xa0\t\r \xa0//return\t\r \xa0type\t\r \xa0of\t\r \xa0the\t\r \xa0function\t\r \xa0is\t\r \xa0void\t\r \xa0\n12. \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0avg\t\r \xa0=\t\r \xa0(a\t\r \xa0+\t\r \xa0b)\t\r \xa0/\t\r \xa02;\t\r \xa0\t\r \xa0\t\r \xa0\ncout<<avg\t\r \xa0<<\t\r \xa0endl;\t\r \xa0\n5. \xa0 }\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0//\t\r \xa0This\t\r \xa0function\t\r \xa0does\t\r \xa0not\t\r \xa0return\t\r \xa0any\t\r \xa0value\t\r \xa0\n6. \xa0 \t\r \xa0\n7. \xa0 int\t\r \xa0main\t\r \xa0()\t\r \xa0{\t\r \xa0\n8. \xa0 \ ...
#  Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 4}, page_content='Why\t\r \xa0do\t\r \xa0we\t\r \xa0need\t\r \xa0function?\t\r \xa0\n• \xa0 Reusability:\t\r \xa0Once\t\r \xa0a\t\r \xa0function\t\r \xa0is\t\r \xa0defined,\t\r \xa0it\t\r \xa0can\t\r \xa0be\t\r \xa0used\t\r \xa0over\t\r \xa0and\t\r \xa0over\t\r \xa0\nagain.\t\r \xa0You\t\r \xa0can\t\r \xa0call\t\r \xa0the\t\r \xa0function\t\r \xa0as\t\r \xa0many\t\r \xa0time\t\r \xa0as\t\r \xa0it\t\r \xa0is\t\r \xa0needed,\t\r \xa0which\t\r \xa0\nsaves\t\r \xa0work.\t\r \xa0Consider\t\r \xa0that\t\r \xa0you\t\r \xa0are\t\r \xa0required\t\r \xa0to\t\r \xa0find\t\r \xa0out\t\r \xa0the\t\r \xa0area\t\r \xa0of\t\r \xa0the\t\r \xa0\ncircle,\t\r \xa0now\t\r \xa0either\t\r \xa0you\t\r \xa0can\t\r \xa0apply\t\r \xa0the\t\r \xa0formula\t\r \xa0every\t\r \xa0time\t\r \xa0to\t\r \xa0get\t\r \xa0the\t\r \xa0area\t\r \xa0\nof\t\r \xa0circle\t\r \xa0or\t\r \xa0you\t\r \xa0can\t\r \xa0make\t\r \xa0a\t\r \xa0function\t\r \xa0for\t\r \xa0finding\t\r \xa0area\t\r \xa0of\t\r \xa0the\t\r \xa0circle\t\r \xa0and\t\r \xa0\ninvoke\t\r \xa0the\t\r \xa0function\t\r \xa0whenever\t\r \xa0it\t\r \xa0is\t\r \xa0needed.\t\r \xa0\n• \xa0 Neat\t\r \xa0code:\t\r \xa0A\t\r \xa0code\t\r \xa0created\t\r \xa0with\t\r \xa0function\t\r \xa0is\t\r \xa0easy\t\r \xa0to\t\r \xa0read\t\r \xa0and\t\r \xa0dry\t\r \xa0run.\t\r \xa0You\t\r \xa0\ndon’t\t\r \xa0need\t\r \xa0to\t\r \xa0type\t\r \xa0the\t\r \xa0same\t\r \xa0statements\t\r \xa0over\t\r \xa0and\t\r \xa0over\t\r \xa0again,\t\r \xa0instead\t\r \xa0\nyou\t\r \xa0can\t\r \xa0invoke\t\r \xa0the\t\r \xa0function\t\r \xa0whenever\t\r \xa0needed.\t\r \xa0\n• \xa0 Modularisation\t\r \xa0–\t\r \xa0Functions\t\r \xa0help\t\r \xa0in\t\r \xa0modularising\t\r \xa0code.\t\r \xa0Modularisation\t\r \xa0\nmeans\t\r \xa0to\t\r \xa0divides\t\r \xa0the\t\r \xa0code\t\r \xa0in\t\r \xa0small\t\r \xa0modules\t\r \xa0each\t\r \xa0performing\t\r \xa0specific\t\r \xa0\ntask.\t\r \xa0Functions\t\r \xa0helps\t\r \xa0in\t\r \xa0doing\t\r \xa0so\t\r \xa0as\t\r \xa0they\t\r \xa0are\t\r \xa0the\t\r \xa0small\t\r \xa0fragments\t\r \xa0of\t\r \xa0the\t\r \xa0\nprogramme\t\r \xa0designed\t\r \xa0to\t\r \xa0perform\t\r \xa0the\t\r \xa0specified\t\r \xa0task.\t\r \xa0\n• \xa0 Easy\t\r \xa0Debugging:\t\r \xa0It\t\r \xa0is\t\r \xa0easy\t\r \xa0to\t\r \xa0find\t\r \xa0and\t\r \xa0correct\t\r \xa0the\t\r \xa0error\t\r \xa0in\t\r \xa0function\t\r \xa0as\t\r \xa0\ncompared\t\r \xa0to\t\r \xa0raw\t\r \xa0code\t\r \xa0without\t\r \xa0function\t\r \xa0where\t\r \xa0you\t\r \xa0must\t\r \xa0correct\t\r \xa0the\t\r \xa0\nerror\t\r \xa0(if\t\r \xa0there\t\r \xa0is\t\r \xa0any)\t\r \xa0everywhere\t\r \xa0the\t\r \xa0specific\t\r \xa0task\t\r \xa0of\t\r \xa0the\t\r \xa0function\t\r \xa0is\t\r \xa0\nperformed.\t\r \xa0\n\t\r \xa0\nHow\t\r \xa0does\t\r \xa0function\t\r \xa0calling\t\r \xa0works?\t\r \xa0\n\t\r \xa0\nConsider\t\r \xa0the\t\r \xa0following\t\r \xa0code\t\r \xa0where\t\r \xa0there\t\r \xa0is\t\r \xa0a\t\r \xa0function\t\r \xa0called\t\r \xa0findsum\t\r \xa0which\t\r \xa0\ncalculates\t\r \xa0and\t\r \xa0returns\t\r \xa0sum\t\r \xa0of\t\r \xa0two\t\r \xa0numbers.\t\r \xa0\n\t\r \xa0\n//Find\t\r \xa0Sum\t\r \xa0of\t\r \xa0two\t\r \xa0integer\t\r \xa0numbers\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\n1. \xa0 #include<iostream>\t\r \xa0\n2. \xa0 using\t\r \xa0namespace\t\r \xa0std;\t\r \xa0\n3. \xa0 int\t\r \xa0findSum(\t\r \xa0int\t\r \xa0a,\t\r \xa0int\t\r \xa0b){\t\r \xa0\t\r \xa0//\t\r \xa0return\t\r \xa0type\t\r \xa0of\t\r \xa0the\t\r \xa0functi ...
#  Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 5}, page_content='The\t\r \xa0function\t\r \xa0being\t\r \xa0called\t\r \xa0is\t\r \xa0called\t\r \xa0callee(here\t\r \xa0it\t\r \xa0is\t\r \xa0findsum\t\r \xa0function)\t\r \xa0and\t\r \xa0the\t\r \xa0\nfunction\t\r \xa0which\t\r \xa0calls\t\r \xa0the\t\r \xa0callee\t\r \xa0is\t\r \xa0called\t\r \xa0the\t\r \xa0caller\t\r \xa0(here\t\r \xa0main\t\r \xa0function\t\r \xa0is\t\r \xa0the\t\r \xa0\ncaller)\t\r \xa0.\t\r \xa0\nWhen\t\r \xa0a\t\r \xa0function\t\r \xa0is\t\r \xa0called,\t\r \xa0programme\t\r \xa0control\t\r \xa0goes\t\r \xa0to\t\r \xa0the\t\r \xa0entry\t\r \xa0point\t\r \xa0of\t\r \xa0the\t\r \xa0\nfunction.\t\r \xa0Entry\t\r \xa0point\t\r \xa0is\t\r \xa0where\t\r \xa0the\t\r \xa0function\t\r \xa0is\t\r \xa0defined.\t\r \xa0So\t\r \xa0focus\t\r \xa0now\t\r \xa0shifts\t\r \xa0to\t\r \xa0\ncallee\t\r \xa0and\t\r \xa0the\t\r \xa0caller\t\r \xa0function\t\r \xa0goes\t\r \xa0in\t\r \xa0paused\t\r \xa0state\t\r \xa0.\t\r \xa0\n\t\r \xa0\nFor\t\r \xa0Example:\t\r \xa0In\t\r \xa0above\t\r \xa0code\t\r \xa0\nentry\t\r \xa0point\t\r \xa0of\t\r \xa0the\t\r \xa0function\t\r \xa0\nfindSum\t\r \xa0()\t\r \xa0is\t\r \xa0at\t\r \xa0line\t\r \xa0number\t\r \xa0\n3.\t\r \xa0So\t\r \xa0when\t\r \xa0at\t\r \xa0line\t\r \xa0number\t\r \xa09\t\r \xa0\nthe\t\r \xa0function\t\r \xa0call\t\r \xa0occurs\t\r \xa0the\t\r \xa0\ncontrol\t\r \xa0goes\t\r \xa0to\t\r \xa0line\t\r \xa0number\t\r \xa0\n3,\t\r \xa0then\t\r \xa0after\t\r \xa0the\t\r \xa0statements\t\r \xa0\nin\t\r \xa0the\t\r \xa0function\t\r \xa0findSum\t\r \xa0()\t\r \xa0\nare\t\r \xa0executed\t\r \xa0the\t\r \xa0\nprogramme\t\r \xa0control\t\r \xa0comes\t\r \xa0\nback\t\r \xa0to\t\r \xa0line\t\r \xa0number\t\r \xa09.\t\r \xa0\n\t\r \xa0\n\t\r \xa0Role\t\r \xa0of\t\r \xa0stack\t\r \xa0in\t\r \xa0function\t\r \xa0\ncalling\t\r \xa0(call\t\r \xa0stack)\t\r \xa0\n\t\r \xa0\n\t\r \xa0A\t\r \xa0call\t\r \xa0stack\t\r \xa0is\t\r \xa0a\t\r \xa0storage\t\r \xa0area\t\r \xa0that\t\r \xa0store\t\r \xa0information\t\r \xa0about\t\r \xa0the\t\r \xa0active\t\r \xa0function\t\r \xa0\nand\t\r \xa0paused\t\r \xa0functions.\t\r \xa0It\t\r \xa0stores\t\r \xa0parameters\t\r \xa0of\t\r \xa0the\t\r \xa0function,\t\r \xa0return\t\r \xa0address\t\r \xa0of\t\r \xa0\nthe\t\r \xa0function\t\r \xa0and\t\r \xa0variables\t\r \xa0of\t\r \xa0the\t\r \xa0function\t\r \xa0that\t\r \xa0are\t\r \xa0created\t\r \xa0statically.\t\r \xa0\nOnce\t\r \xa0the\t\r \xa0function\t\r \xa0statements\t\r \xa0are\t\r \xa0terminated\t\r \xa0or\t\r \xa0the\t\r \xa0function\t\r \xa0has\t\r \xa0returned\t\r \xa0a\t\r \xa0\nvalue,\t\r \xa0the\t\r \xa0call\t\r \xa0stack\t\r \xa0removes\t\r \xa0all\t\r \xa0the\t\r \xa0information\t\r \xa0about\t\r \xa0that\t\r \xa0function\t\r \xa0from\t\r \xa0the\t\r \xa0\nstack.\t\r \xa0\n\t\r \xa0\nBenefits\t\r \xa0of\t\r \xa0functions\t\r \xa0\n• \xa0 Modularisation\t\r \xa0\n• \xa0 Easy\t\r \xa0Debugging:\t\r \xa0It\t\r \xa0is\t\r \xa0easy\t\r \xa0to\t\r \xa0find\t\r \xa0and\t\r \xa0correct\t\r \xa0the\t\r \xa0error\t\r \xa0in\t\r \xa0function\t\r \xa0as\t\r \xa0\ncompared\t\r \xa0to\t\r \xa0raw\t\r \xa0code\t\r \xa0without\t\r \xa0function\t\r \xa0where\t\r \xa0you\t\r \xa0must\t\r \xa0correct\t\r \xa0the\t\r \xa0\nerror\t\r \xa0(if\t\r \xa0there\t\r \xa0is\t\r \xa0any)\t\r \xa0everywhere\t\r \xa0the\t\r \xa0specific\t\r \xa0task\t\r \xa0of\t\r \xa0the\t\r \xa0function\t\r \xa0is\t\r \xa0\nperformed.\t\r \xa0\n• \xa0 \t\r \xa0Neat\t\r \xa0code:\t\r \xa0A\t\r \xa0code\t\r \xa0created\t\r ...
#  Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 6}, page_content='Variables\t\r \xa0and\t\r \xa0Scopes\t\r \xa0\n\t\r \xa0\nLocal\t\r \xa0Variables\t\r \xa0\nLocal\t\r \xa0variable\t\r \xa0is\t\r \xa0a\t\r \xa0variable\t\r \xa0that\t\r \xa0is\t\r \xa0given\t\r \xa0a\t\r \xa0local\t\r \xa0scope.\t\r \xa0Local\t\r \xa0variable\t\r \xa0belonging\t\r \xa0\nto\t\r \xa0a\t\r \xa0function\t\r \xa0or\t\r \xa0a\t\r \xa0block\t\r \xa0overrides\t\r \xa0any\t\r \xa0other\t\r \xa0variable\t\r \xa0with\t\r \xa0same\t\r \xa0name\t\r \xa0in\t\r \xa0the\t\r \xa0\nlarger\t\r \xa0scope.\t\r \xa0Scope\t\r \xa0of\t\r \xa0a\t\r \xa0variable\t\r \xa0is\t\r \xa0part\t\r \xa0of\t\r \xa0a\t\r \xa0programme\t\r \xa0for\t\r \xa0which\t\r \xa0this\t\r \xa0variable\t\r \xa0\nis\t\r \xa0accessible.\t\r \xa0\nExample:\t\r \xa0\n1. \xa0 #include<iostream>\t\r \xa0\n2. \xa0 using\t\r \xa0namespace\t\r \xa0std;\t\r \xa0\n3. \xa0 int\t\r \xa0main(){\t\r \xa0\n4. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0a\t\r \xa0=\t\r \xa010;\t\r \xa0\n5. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0if\t\r \xa0(1){\t\r \xa0\n6. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0a\t\r \xa0=\t\r \xa05;\t\r \xa0\n7. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0cout<<\t\r \xa0a<<endl;\t\r \xa0\n8. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0}\t\r \xa0\n9. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0cout<<\t\r \xa0a;\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\n10. \xa0}\t\r \xa0\n\t\r \xa0\nOutput\t\r \xa0\n5\t\r \xa0\n10\t\r \xa0\nIn\t\r \xa0the\t\r \xa0above\t\r \xa0code\t\r \xa0the\t\r \xa0variable\t\r \xa0a\t\r \xa0declared\t\r \xa0inside\t\r \xa0the\t\r \xa0block\t\r \xa0after\t\r \xa0if\t\r \xa0statement\t\r \xa0is\t\r \xa0\na\t\r \xa0local\t\r \xa0variable\t\r \xa0for\t\r \xa0this\t\r \xa0block\t\r \xa0and\t\r \xa0is\t\r \xa0different\t\r \xa0from\t\r \xa0the\t\r \xa0the\t\r \xa0variable\t\r \xa0a\t\r \xa0declared\t\r \xa0\noutside\t\r \xa0this\t\r \xa0block.\t\r \xa0Both\t\r \xa0these\t\r \xa0variable\t\r \xa0are\t\r \xa0allocated\t\r \xa0to\t\r \xa0different\t\r \xa0memory.\t\r \xa0\nLifetime\t\r \xa0of\t\r \xa0a\t\r \xa0Variable\t\r \xa0\nThe\t\r \xa0lifetime\t\r \xa0of\t\r \xa0a\t\r \xa0variable\t\r \xa0is\t\r \xa0the\t\r \xa0time\t\r \xa0period\t\r \xa0for\t\r \xa0which\t\r \xa0the\t\r \xa0declared\t\r \xa0variable\t\r \xa0has\t\r \xa0\na\t\r \xa0valid\t\r \xa0memory.\t\r \xa0Scope\t\r \xa0and\t\r \xa0lifetime\t\r \xa0of\t\r \xa0a\t\r \xa0variable\t\r \xa0are\t\r \xa0two\t\r \xa0different\t\r \xa0concepts,\t\r \xa0\nscope\t\r \xa0of\t\r \xa0a\t\r \xa0variable\t\r \xa0is\t\r \xa0part\t\r \xa0of\t\r \xa0a\t\r \xa0programme\t\r \xa0for\t\r \xa0which\t\r \xa0this\t\r \xa0variable\t\r \xa0is\t\r \xa0accessible\t\r \xa0\nwhereas\t\r \xa0lifetime\t\r \xa0is\t\r \xa0duration\t\r \xa0for\t\r \xa0which\t\r \xa0this\t\r \xa0variable\t\r \xa0has\t\r \xa0a\t\r \xa0\t\r \xa0valid\t\r \xa0memory.\t\r \xa0\nLoop\t\r \xa0variable\t\r \xa0\nLoop\t\r \xa0variable\t\r \xa0is\t\r \xa0a\t\r \xa0variable\t\r \xa0which\t\r \xa0defines\t\r \xa0the\t\r \xa0loop\t\r \xa0 ...
#  Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 7}, page_content='“for\t\r \xa0(int\t\r \xa0i\t\r \xa0=\t\r \xa00;\t\r \xa0i\t\r \xa0<\t\r \xa03;\t\r \xa0i++)\t\r \xa0{\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0//\t\r \xa0variable\t\r \xa0i\t\r \xa0is\t\r \xa0the\t\r \xa0loop\t\r \xa0variable\t\r \xa0\n\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0…….;\t\r \xa0\n\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0……..;\t\r \xa0\n\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0statements;\t\r \xa0\n\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0}\t\r \xa0“\t\r \xa0\nFor\t\r \xa0this\t\r \xa0example,\t\r \xa0variable\t\r \xa0i\t\r \xa0is\t\r \xa0the\t\r \xa0loop\t\r \xa0variable.\t\r \xa0\n\t\r \xa0\nVariables\t\r \xa0in\t\r \xa0the\t\r \xa0same\t\r \xa0scope\t\r \xa0\nScope\t\r \xa0is\t\r \xa0part\t\r \xa0of\t\r \xa0programme\t\r \xa0where\t\r \xa0the\t\r \xa0declared\t\r \xa0variable\t\r \xa0is\t\r \xa0accessible.\t\r \xa0In\t\r \xa0the\t\r \xa0\nsame\t\r \xa0scope,\t\r \xa0no\t\r \xa0two\t\r \xa0variables\t\r \xa0can\t\r \xa0have\t\r \xa0name.\t\r \xa0However,\t\r \xa0it\t\r \xa0is\t\r \xa0possible\t\r \xa0for\t\r \xa0two\t\r \xa0\nvariables\t\r \xa0to\t\r \xa0have\t\r \xa0same\t\r \xa0name\t\r \xa0if\t\r \xa0they\t\r \xa0are\t\r \xa0declared\t\r \xa0in\t\r \xa0different\t\r \xa0scope.\t\r \xa0\nExample:\t\r \xa0\t\r \xa0\n\t\r \xa0\n1. \xa0 #include<iostream>\t\r \xa0\n2. \xa0 using\t\r \xa0namespace\t\r \xa0std;\t\r \xa0\n3. \xa0 int\t\r \xa0main\t\r \xa0()\t\r \xa0{\t\r \xa0\n4. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0a\t\r \xa0=\t\r \xa010;\t\r \xa0\n5. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0a\t\r \xa0=\t\r \xa05;\t\r \xa0//\t\r \xa0two\t\r \xa0variables\t\r \xa0with\t\r \xa0same\t\r \xa0name,\t\r \xa0the\t\r \xa0code\t\r \xa0will\t\r \xa0not\t\r \xa0\ncompile\t\r \xa0\t\r \xa0\n6. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0cout<<\t\r \xa0a;\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\n7. \xa0 }\t\r \xa0\nFor\t\r \xa0the\t\r \xa0above\t\r \xa0code,\t\r \xa0there\t\r \xa0are\t\r \xa0two\t\r \xa0variables\t\r \xa0with\t\r \xa0same\t\r \xa0name\t\r \xa0a\t\r \xa0in\t\r \xa0the\t\r \xa0same\t\r \xa0\nscope\t\r \xa0of\t\r \xa0main\t\r \xa0()\t\r \xa0function.\t\r \xa0Hence\t\r \xa0the\t\r \xa0above\t\r \xa0code\t\r \xa0will\t\r \xa0not\t\r \xa0compile.\t\r \xa0\nBut\t\r \xa0the\t\r \xa0code\t\r \xa0given\t\r \xa0below\t\r \xa0will\t\r \xa0compile\t\r \xa0because\t\r \xa0the\t\r \xa0two\t\r \xa0variables\t\r \xa0with\t\r \xa0same\t\r \xa0\nname\t\r \xa0a\t\r \xa0are\t\r \xa0declared\t\r \xa0in\t\r \xa0different\t\r \xa0scope.\t\r \xa0\t\r \xa0\n1. \xa0 #include<iostream>\t\r \xa0\n2. \xa0 using\t\r \xa0namespace\t\r \xa0std;\t\r \xa0\n3. \xa0 int\t\r \xa0main\t\r \xa0()\t\r \xa0{\t\r \xa0\n4. \xa0 \t\r \xa0\t\r \x ...
#  Document(metadata={'producer': 'Mac OS X 10.10.5 Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20170618173632Z00'00'", 'source': '..\\data\\pdf\\functions_coding ninjas.pdf', 'file_path': '..\\data\\pdf\\functions_coding ninjas.pdf', 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Microsoft Word -  C1_L5_Functions.docx', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20170618173632Z00'00'", 'trapped': '', 'modDate': "D:20170618173632Z00'00'", 'creationDate': "D:20170618173632Z00'00'", 'page': 8}, page_content='When\t\r \xa0the\t\r \xa0parameters\t\r \xa0are\t\r \xa0passed\t\r \xa0to\t\r \xa0a\t\r \xa0function\t\r \xa0by\t\r \xa0pass\t\r \xa0by\t\r \xa0value\t\r \xa0method,\t\r \xa0then\t\r \xa0\nthe\t\r \xa0formal\t\r \xa0parameters\t\r \xa0are\t\r \xa0allocated\t\r \xa0to\t\r \xa0a\t\r \xa0new\t\r \xa0memory.\t\r \xa0These\t\r \xa0parameters\t\r \xa0have\t\r \xa0\nsame\t\r \xa0value\t\r \xa0as\t\r \xa0that\t\r \xa0of\t\r \xa0actual\t\r \xa0parameters.\t\r \xa0Since\t\r \xa0the\t\r \xa0formal\t\r \xa0parameters\t\r \xa0are\t\r \xa0\nallocated\t\r \xa0to\t\r \xa0new\t\r \xa0memory\t\r \xa0any\t\r \xa0changes\t\r \xa0in\t\r \xa0these\t\r \xa0parameters\t\r \xa0will\t\r \xa0not\t\r \xa0reflect\t\r \xa0to\t\r \xa0\nactual\t\r \xa0parameters.\t\r \xa0\n\t\r \xa0\nExample:\t\r \xa0\n\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0//Function\t\r \xa0to\t\r \xa0increase\t\r \xa0the\t\r \xa0parameters\t\r \xa0value\t\r \xa0\n1. \xa0 #include<iostream>\t\r \xa0\n2. \xa0 using\t\r \xa0namespace\t\r \xa0std;\t\r \xa0\n3. \xa0 void\t\r \xa0increment\t\r \xa0(int\t\r \xa0x,\t\r \xa0int\t\r \xa0y)\t\r \xa0{\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0//\t\r \xa0x\t\r \xa0and\t\r \xa0y\t\r \xa0are\t\r \xa0formal\t\r \xa0parameters\t\r \xa0\t\r \xa0\n4. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0x++;\t\r \xa0\n5. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0y\t\r \xa0=\t\r \xa0y\t\r \xa0+\t\r \xa02;\t\r \xa0\n6. \xa0 \t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0cout<<x<<”:\t\r \xa0“<<y<<endl;\t\r \xa0\n7. \xa0 }\t\r \xa0\n8. \xa0 \t\r \xa0\n9. \xa0 int\t\r \xa0main\t\r \xa0()\t\r \xa0{\t\r \xa0\n10. \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0int\t\r \xa0a\t\r \xa0=\t\r \xa010,\t\r \xa0b\t\r \xa0=\t\r \xa020;\t\r \xa0\n11. \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0increment\t\r \xa0(a,\t\r \xa0b);\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0//\t\r \xa0a\t\r \xa0and\t\r \xa0b\t\r \xa0are\t\r \xa0actual\t\r \xa0parameters\t\r \xa0\t\r \xa0\n12. \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0cout<<\t\r \xa0a<<”:\t\r \xa0“<<b;\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\t\r \xa0\n13. \xa0}\t\r \xa0\n\t\r \xa0\n\t\r \xa0\nOutput:\t\r \xa0\n11:\t\r \xa022\t\r \xa0\n10:\t\r \xa020\t\r \xa0\t\r \xa0\n\t\r \xa0\nFor\t\r \xa0the\t\r \xa0above\t\r \xa0code,\t\r \xa0changes\t\r \xa0in\t\r \xa0the\t\r \xa0values\t\r \xa0of\t\r \xa0x\t\r \xa0and\t\r \xa0y\t\r \xa0are\t\r \xa0not\t\r \xa0reflected\t\r \xa0to\t\r \xa0\na\t\r \xa0and\t\r \xa0b\t\r \xa0because\t\r \xa0x\t\r \xa0and\t\r ...
